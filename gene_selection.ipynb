# %%
import pandas as pd

# %%
flowers = ['rose', 'cosmo','lily','pansy','hyacinth','tulip','mum','windflower']

# %%
flower_genes_table = {}
flower_genes = {}
for flower in flowers:
    flower_genes_table[flower] = pd.read_csv('genes_table/'+flower+'_genes_table.csv')
    flower_genes[flower] = pd.read_csv('genes_table/'+flower+'_all_genes.csv')

# %%
flower_picture = pd.read_csv('source/flower_picture.csv')

# %%
mum = flower_genes['mum']

# %%
mum_genes = flower_genes_table['mum']

# %%
mum
# Out:
#        genes          color
# 0   RR-yy-WW     Red (seed)
# 1   rr-YY-WW  Yellow (seed)
# 2   rr-yy-Ww   White (seed)
# 3   Rr-yy-WW           Pink
# 4   Rr-yy-Ww           Pink
# 5   rr-Yy-WW         Yellow
# 6   rr-Yy-Ww         Yellow
# 7   rr-yy-WW          White
# 8   rr-yy-ww         Purple
# 9   RR-yy-Ww            Red
# 10  RR-yy-ww            Red
# 11  Rr-yy-ww           Pink
# 12  rr-YY-Ww         Yellow
# 13  rr-YY-ww         Yellow
# 14  rr-Yy-ww          White

# %%
flower_picture
# Out:
#     ID (Buds)        Type   Color  Inventory Icon  \
# 0     60016.0      Cosmos     Red             NaN
# 1     60019.0      Cosmos   White             NaN
# 2     60042.0      Cosmos  Yellow             NaN
# 3     60151.0      Cosmos   Black             NaN
# 4     60157.0      Cosmos  Orange             NaN
# 5     60159.0      Cosmos    Pink             NaN
# 6     60222.0       Tulip   White             NaN
# 7     60225.0       Tulip     Red             NaN
# 8     60228.0       Tulip  Yellow             NaN
# 9     60231.0       Tulip    Pink             NaN
# 10    60234.0       Tulip  Orange             NaN
# 11    60237.0       Tulip  Purple             NaN
# 12    60240.0       Tulip   Black             NaN
# 13    60243.0       Pansy   White             NaN
# 14    60246.0       Pansy     Red             NaN
# 15    60249.0       Pansy  Yellow             NaN
# 16    60252.0       Pansy  Orange             NaN
# 17    60255.0       Pansy  Purple             NaN
# ...
