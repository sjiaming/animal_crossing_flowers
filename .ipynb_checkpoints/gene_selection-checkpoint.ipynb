# %%
import pandas as pd

# %%
flowers = ['rose', 'cosmos','lily','pansy','hyacinth','tulip','mum','windflower']

# %%
flower_genes = {}
for flower in flowers:
    flower_genes[flower] = pd.read_csv('flower_genes/'+flower+'_genes.csv')

# %%
flower_picture = pd.read_csv('flower_picture.csv')

# %%
flower_genes['rose']
# Out:
#                       breading_pair  \
# 0    ['RR-yy-WW-Ss', 'RR-yy-WW-Ss']
# 1    ['RR-yy-WW-Ss', 'rr-yy-Ww-ss']
# 2    ['rr-YY-WW-ss', 'rr-YY-WW-ss']
# 3    ['rr-YY-WW-ss', 'rr-yy-Ww-ss']
# 4    ['rr-yy-Ww-ss', 'rr-yy-Ww-ss']
# ..                              ...
# 499  ['rr-yy-ww-SS', 'rr-yy-ww-SS']
# 500  ['rr-yy-ww-SS', 'rr-yy-ww-Ss']
# 501  ['rr-yy-ww-SS', 'rr-yy-ww-ss']
# 502  ['rr-yy-ww-Ss', 'rr-yy-ww-Ss']
# 503  ['rr-yy-ww-Ss', 'rr-yy-ww-ss']
#
#                                       breading_results  \
# 0        ['RR-yy-WW-SS', 'RR-yy-WW-Ss', 'RR-yy-WW-ss']
# 1    ['Rr-yy-WW-Ss', 'Rr-yy-WW-ss', 'Rr-yy-Ww-Ss', ...
# 2                                      ['rr-YY-WW-ss']
# 3                       ['rr-Yy-WW-ss', 'rr-Yy-Ww-ss']
# 4        ['rr-yy-WW-ss', 'rr-yy-Ww-ss', 'rr-yy-ww-ss']
# ..                                                 ...
# 499                                    ['rr-yy-ww-SS']
# 500                     ['rr-yy-ww-SS', 'rr-yy-ww-Ss']
# ...

# %%
flower_picture
# Out:
#     ID (Buds)        Type   Color  Inventory Icon  \
# 0     60016.0      Cosmos     Red             NaN
# 1     60019.0      Cosmos   White             NaN
# 2     60042.0      Cosmos  Yellow             NaN
# 3     60151.0      Cosmos   Black             NaN
# 4     60157.0      Cosmos  Orange             NaN
# 5     60159.0      Cosmos    Pink             NaN
# 6     60222.0       Tulip   White             NaN
# 7     60225.0       Tulip     Red             NaN
# 8     60228.0       Tulip  Yellow             NaN
# 9     60231.0       Tulip    Pink             NaN
# 10    60234.0       Tulip  Orange             NaN
# 11    60237.0       Tulip  Purple             NaN
# 12    60240.0       Tulip   Black             NaN
# 13    60243.0       Pansy   White             NaN
# 14    60246.0       Pansy     Red             NaN
# 15    60249.0       Pansy  Yellow             NaN
# 16    60252.0       Pansy  Orange             NaN
# 17    60255.0       Pansy  Purple             NaN
# ...
